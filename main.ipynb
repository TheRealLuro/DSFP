# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

unclean_csv = pd.read_csv(filepath_or_buffer='./student_data.csv')

# %%
unclean_csv
# Out:
#       StudentID  Age  Gender         Ethnicity ParentalEducation  \
# 0          1001   17       1         Caucasian      Some College
# 1          1002   18       0         Caucasian       High School
# 2          1003   15       0             Asian        Bachelor's
# 3          1004   17       1         Caucasian        Bachelor's
# 4          1005   17       1         Caucasian      Some College
# ...         ...  ...     ...               ...               ...
# 2387       3388   18       1         Caucasian        Bachelor's
# 2388       3389   17       0         Caucasian       High School
# 2389       3390   16       1         Caucasian      Some College
# 2390       3391   16       1  African American               NaN
# 2391       3392   16       1         Caucasian      Some College
#
#       StudyTimeWeekly  Absences  Tutoring ParentalSupport  Extracurricular  \
# 0           19.833723       7.0         1        Moderate                0
# ...

# %%
unclean_csv.tail(10)
# Out:
#       StudentID  Age  Gender         Ethnicity ParentalEducation  \
# 2382       3383   16       0         Caucasian        Bachelor's
# 2383       3384   16       1             Asian      Some College
# 2384       3385   15       1         Caucasian       High School
# 2385       3386   16       1         Caucasian       High School
# 2386       3387   16       0         Caucasian      Some College
# 2387       3388   18       1         Caucasian        Bachelor's
# 2388       3389   17       0         Caucasian       High School
# 2389       3390   16       1         Caucasian      Some College
# 2390       3391   16       1  African American               NaN
# 2391       3392   16       1         Caucasian      Some College
#
#       StudyTimeWeekly  Absences  Tutoring ParentalSupport  Extracurricular  \
# 2382        13.941823      20.0         0        Moderate                0
# 2383        11.736409      18.0         1       Very High                0
# ...

# %%
unclean_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   object
#  4   ParentalEducation  2149 non-null   object
#  5   StudyTimeWeekly    2345 non-null   float64
#  6   Absences           2321 non-null   float64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2180 non-null   object
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       72 non-null     float64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(5), int64(7), object(3)
# ...

# %%
# STUDENT IDS VERIFIED
invalid_count = 0
seen_entries = []
for index, obj in unclean_csv.iterrows():
    if obj['StudentID'] > 3392 or obj['StudentID'] < 1001:
        print("INVALID ENTRY " + str(obj['StudentID']))
        invalid_count += 1
    elif obj['StudentID'] in seen_entries:
        print("DUPLICATE ENTRY " + str(obj['StudentID']))
        invalid_count += 1
    else:
        seen_entries.append(obj['StudentID'])
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
# AGE VERIFIED
invalid_count = 0
for index, obj in unclean_csv.iterrows():
    if obj['Age'] > 18 or obj['Age'] < 15:
        print("INVALID ENTRY " + str(obj['Age']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
# GENDERS VERIFIED
unclean_csv['Gender'] = unclean_csv['Gender'].dropna()

invalid_count = 0
for index, obj in unclean_csv.iterrows():
    if obj['Gender'] not in [0, 1]:
        print("INVALID ENTRY " + str(obj['Gender']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
# ETHNICITY VERIFIED
unclean_csv['Ethnicity'].value_counts()
unclean_csv['Ethnicity'].isna().sum()
# Out:
# np.int64(0)

# %%
# PARENTAL EDUCATION VERIFIED
unclean_csv['ParentalEducation'].isna().sum()
unclean_csv['ParentalEducation'].value_counts()
# Out:
# ParentalEducation
# Some College    934
# High School     728
# Bachelor's      367
# Higher          120
# Name: count, dtype: int64

# %%
unclean_csv['ParentalEducation'] = unclean_csv['ParentalEducation'].fillna('None')
unclean_csv['ParentalEducation'].value_counts()
# Out:
# ParentalEducation
# Some College    934
# High School     728
# Bachelor's      367
# None            243
# Higher          120
# Name: count, dtype: int64

# %%
# STUDY TIME WEEKLY VERIFIED
unclean_csv['StudyTimeWeekly'].isna().sum()
unclean_csv['StudyTimeWeekly'] = unclean_csv['StudyTimeWeekly'].fillna(0.0)
unclean_csv['StudyTimeWeekly'].isna().sum()
# Out:
# np.int64(0)

# %%
unclean_csv['StudyTimeWeekly'].plot(kind='box')
# Out:
# <Axes: >

# %%
unclean_csv['StudyTimeWeekly'].plot(kind='hist', bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
unclean_csv['Absences'].dtype
# That's an issue, let's correct it.
# Out:
# dtype('float64')

# %%
# ABSENCES VERIFIED
unclean_csv['Absences'].isna().sum()
unclean_csv['Absences'] = unclean_csv['Absences'].fillna(0)

invalid_count = 0
for index, obj in unclean_csv.iterrows():
    if (obj['Absences'] % 1) != 0:
        print('INVALID ENTRY ' + str(obj['Absences']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
unclean_csv['Absences'].plot(kind='box')
# Out:
# <Axes: >

# %%
# TUTORING VERIFIED
unclean_csv['Tutoring'].isna().sum()
invalid_count = 0
for index, obj in unclean_csv.iterrows():
    if obj['Tutoring'] not in [0, 1]:
        print("INVALID ENTRY " + str(obj['Tutoring']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# Complete! Error count: 47

# %%
# They are all 11's, we can just... change them to 1's.
unclean_csv['Tutoring'] = unclean_csv['Tutoring'].replace(11, 1)
invalid_count = 0
for index, obj in unclean_csv.iterrows():
    if obj['Tutoring'] not in [0, 1]:
        print("INVALID ENTRY " + str(obj['Tutoring']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
#PARENTAL SUPPORT VERIFIED
unclean_csv['ParentalSupport'].isna().sum()
unclean_csv['ParentalSupport'].value_counts()
unclean_csv['ParentalSupport'] = unclean_csv['ParentalSupport'].fillna('None')
unclean_csv['ParentalSupport'].value_counts()
# Out:
# ParentalSupport
# Moderate     740
# High         697
# Low          489
# Very High    254
# None         212
# Name: count, dtype: int64

# %%
# EXTRACURRICULAR ACTIVITIES VERIFIED
for index, obj in unclean_csv.iterrows():
    if obj['Extracurricular'] not in [0, 1]:
        print("INVALID ENTRY " + str(obj['Extracurricular']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
# SPORTS VERIFIED
for index, obj in unclean_csv.iterrows():
    if obj['Sports'] not in [0, 1]:
        print("INVALID ENTRY " + str(obj['Sports']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# INVALID ENTRY 11
# Complete! Error count: 47

# %%
# Same crap different day, correct the 11's to 1's
unclean_csv['Sports'] = unclean_csv['Sports'].replace(11, 1)
invalid_count = 0
for index, obj in unclean_csv.iterrows():
    if obj['Sports'] not in [0, 1]:
        print("INVALID ENTRY " + str(obj['Sports']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
# MUSIC VERIFIED
invalid_count = 0
for index, obj in unclean_csv.iterrows():
    if obj['Music'] not in [0, 1]:
        print("INVALID ENTRY " + str(obj['Music']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
# Volunteering VERIFIED
unclean_csv['Volunteering'] = unclean_csv['Volunteering'].fillna(0)
invalid_count = 0
for index, obj in unclean_csv.iterrows():
    if obj['Volunteering'] not in [0, 1]:
        print("INVALID ENTRY " + str(obj['Volunteering']))
        invalid_count += 1
print("Complete! Error count: " + str(invalid_count))
# Out:
# Complete! Error count: 0

# %%
# GPA VERIFIED
unclean_csv['GPA'].isna().sum()
# Out:
# np.int64(0)

# %%
# All values OK
unclean_csv['GPA'].plot(kind='box')
# Out:
# <Axes: >

# %%
unclean_csv['GradeClass'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # [GradeClass]
# This column is technically "filled", but we shouldn't trust it, since it's rebuildable from the GPA column, which had no NA values. Thus, lets purge it and rebuild.
#
# - 0 = >= 3.5
# - 1 = 30.3 - 3.49
# - 2 = 2.5-2.99
# - 3 = 2.0-2.49
# - 4 = <2.0

# %%
for index, obj in unclean_csv.iterrows():
    if obj['GPA'] >= 3.5:
        unclean_csv.at[index, 'GradeClass'] = 0
    elif obj['GPA'] >= 3.0:
        unclean_csv.at[index, 'GradeClass'] = 1
    elif obj['GPA'] >= 2.5:
        unclean_csv.at[index, 'GradeClass'] = 2
    elif obj['GPA'] >= 2.0:
        unclean_csv.at[index, 'GradeClass'] = 3
    else:
        unclean_csv.at[index, 'GradeClass'] = 4
unclean_csv['GradeClass'].value_counts()
# Out:
# GradeClass
# 4.0    1274
# 3.0     412
# 2.0     385
# 1.0     244
# 0.0      77
# Name: count, dtype: int64

# %%
unclean_csv.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity             object
# ParentalEducation     object
# StudyTimeWeekly      float64
# Absences             float64
# Tutoring               int64
# ParentalSupport       object
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering         float64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
unclean_csv.head(5)
# Out:
#    StudentID  Age  Gender  Ethnicity ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1  Caucasian      Some College        19.833723
# 1       1002   18       0  Caucasian       High School        15.408756
# 2       1003   15       0      Asian        Bachelor's         4.210570
# 3       1004   17       1  Caucasian        Bachelor's        10.028829
# 4       1005   17       1  Caucasian      Some College         4.672495
#
#    Absences  Tutoring ParentalSupport  Extracurricular  Sports  Music  \
# 0       7.0         1        Moderate                0       0      1
# 1       0.0         0             Low                0       0      0
# 2      26.0         0        Moderate                0       0      0
# 3      14.0         0            High                1       0      0
# 4      17.0         1            High                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0           0.0  2.929196         2.0
# ...

# %% [markdown]
# #### Finally, lets condense the database down to proper integer types. While this doesn't matter for saving it, if we began to actually use this dataset, it would be a big deal.

# %%
clean_csv = unclean_csv.copy()

# %%
clean_csv['StudentID'] = clean_csv['StudentID'].astype(np.int16)
clean_csv['Age'] = clean_csv['Age'].astype(np.int8)
clean_csv['Gender'] = clean_csv['Gender'].astype(np.int8)
clean_csv['Absences'] = clean_csv['Absences'].astype(np.int8)
clean_csv['Tutoring'] = clean_csv['Tutoring'].astype(np.int8)
clean_csv['Extracurricular'] = clean_csv['Extracurricular'].astype(np.int8)
clean_csv['Sports'] = clean_csv['Sports'].astype(np.int8)
clean_csv['Music'] = clean_csv['Music'].astype(np.int8)
clean_csv['Volunteering'] = clean_csv['Volunteering'].astype(np.int8)
clean_csv['GradeClass'] = clean_csv['GradeClass'].astype(np.int8)

clean_csv['GPA'] = clean_csv['GPA'].astype(np.float32)
clean_csv['StudyTimeWeekly'] = clean_csv['StudyTimeWeekly'].astype(np.float32)

# %%
unclean_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   object
#  4   ParentalEducation  2392 non-null   object
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   float64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   object
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   float64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(5), int64(7), object(3)
# ...

# %%
clean_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int16
#  1   Age                2392 non-null   int8
#  2   Gender             2392 non-null   int8
#  3   Ethnicity          2392 non-null   object
#  4   ParentalEducation  2392 non-null   object
#  5   StudyTimeWeekly    2392 non-null   float32
#  6   Absences           2392 non-null   int8
#  7   Tutoring           2392 non-null   int8
#  8   ParentalSupport    2392 non-null   object
#  9   Extracurricular    2392 non-null   int8
#  10  Sports             2392 non-null   int8
#  11  Music              2392 non-null   int8
#  12  Volunteering       2392 non-null   int8
#  13  GPA                2392 non-null   float32
#  14  GradeClass         2392 non-null   int8
# dtypes: float32(2), int16(1), int8(9), object(3)
# ...

# %% [markdown]
# ### Over 100KB less, and now cleaned. Yippie
# (As mentioned, I know this doesn't do anything when saving to CSV, but if we were to use this dataset in an application, which would happen after cleaning, it would be a big deal)

# %%
clean_csv.to_csv(path_or_buf='./student_data_cleaned.csv', index=False)

# %% [markdown]
# # GRAPHING AND DATA EXPLORATION

# %%
clean_csv.head(5)
# Out:
#    StudentID  Age  Gender  Ethnicity ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1  Caucasian      Some College        19.833723
# 1       1002   18       0  Caucasian       High School        15.408756
# 2       1003   15       0      Asian        Bachelor's         4.210570
# 3       1004   17       1  Caucasian        Bachelor's        10.028830
# 4       1005   17       1  Caucasian      Some College         4.672495
#
#    Absences  Tutoring ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1        Moderate                0       0      1
# 1         0         0             Low                0       0      0
# 2        26         0        Moderate                0       0      0
# 3        14         0            High                1       0      0
# 4        17         1            High                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196           2
# ...

# %%
graphing_df = clean_csv.copy()

# %%
plt.scatter(graphing_df["StudyTimeWeekly"], graphing_df["GPA"], c=graphing_df['Absences'],cmap="viridis", alpha=0.5)
plt.xlabel("Weekly Study Time (hrs)")
plt.ylabel("GPA")
plt.title("Study Time vs GPA vs Absences")
plt.colorbar(label="Absences")
plt.show()

# %%
graphing_df.groupby("GradeClass")["Absences"].mean().plot(kind="bar")
plt.ylabel("Average Absences")
plt.title("Absences by GPA")
plt.xticks([0, 1, 2, 3, 4], ['>= 3.5', '3.0-3.49', '2.5-2.99', '2.0-2.49', '< 2.0'], rotation=0)
plt.show()

# %%
for index, obj in unclean_csv.iterrows():
    if obj['Extracurricular'] == 1 or obj['Sports'] == 1 or obj['Music'] == 1 or obj['Volunteering'] == 1:
        unclean_csv.at[index, 'DidAnyExtra'] = 1
    else:
        unclean_csv.at[index, 'DidAnyExtra'] = 0
unclean_csv['DidAnyExtra'].value_counts()
# Out:
# DidAnyExtra
# 1.0    1599
# 0.0     793
# Name: count, dtype: int64

# %%
unclean_csv.groupby("DidAnyExtra")["GPA"].mean().plot(kind="bar")
plt.xticks([0,1], ["No", "Yes"], rotation=0)
plt.ylabel("Average GPA")
plt.xlabel("Did any Extracurricular Activity")
plt.title("Average GPA by Any Special Activity")
plt.show()

# %%
order = ["None", "High School", "Some College", "Bachelor's", "Higher"]
unclean_csv.groupby("ParentalEducation")["GPA"].mean().reindex(order).plot(kind="bar")

plt.ylabel("Average GPA")
plt.xlabel("Parents Education Level")
plt.title("Average GPA by Parental Education")
plt.show()🫩
# Out:
#   Cell In[42], line 7
#     plt.show()🫩
#               ^
# SyntaxError: invalid non-printable character U+1FAE9

# %%
graphing_df.groupby("Age")["GradeClass"].mean().plot(kind="bar")
plt.ylabel("Average GPA")
plt.title("GPA by Age")
plt.show()
